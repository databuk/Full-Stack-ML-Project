# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
# %pwd
# Out:
# 'c:\\Users\\Ibk\\Desktop\\data project\\full-stack-ml-project'

# %%
import os
os.chdir("full-stack-ml-project")

# %%
from dsProject.constants import *
from dsProject.utils.common import *

class ConfigurationManager:
    def __init__(self,
                 config_filepath=CONFIG_FILE_PATH,
                 param_filepath=PARAMS_FILE_PATH,
                 schema_filepath=SCHEMA_FILE_PATH):
        
        self.config = read_yaml(config_filepath)
        self.param = read_yaml(param_filepath)
        self.schema = read_yaml(schema_filepath)
        create_directories([self.config.artifact_root])
    def get_data_transformation(self)-> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])
        
        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config
        
    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path)
        train, test = train_test_split(data)
        train.to_csv(os.path.join(self.config.root_dir,"train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"), index=False)
        logger.info("Splitted data into training and test set. ")
        logger.info(train.shape)
        logger.info(test.shape)
        print(train.shape)
        print(test.shape)

# %%
config = ConfigurationManager()
data_transformation_config = config.get_data_transformation()
data_transformation = DataTransformation(data_transformation_config)
data_transformation.train_test_splitting()
# Out:
# 2026-07-28 18:31:48,835 | INFO | common| YAML file: config\config.yaml loaded successfully.
# 2026-07-28 18:31:48,840 | INFO | common| YAML file: params.yaml loaded successfully.
# 2026-07-28 18:31:48,843 | INFO | common| YAML file: schema.yaml loaded successfully.
# 2026-07-28 18:31:48,844 | INFO | common| Directory created at: artifacts
# 2026-07-28 18:31:48,846 | INFO | common| Directory created at: artifacts/data_transformation
# 2026-07-28 18:31:48,876 | INFO | 1437508068| Splitted data into training and test set.
# 2026-07-28 18:31:48,878 | INFO | 1437508068| (1199, 12)
# 2026-07-28 18:31:48,881 | INFO | 1437508068| (400, 12)
# (1199, 12)
# (400, 12)
